# %% [markdown]
# # Import libraries

# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yfinance
#   Downloading yfinance-0.1.87-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.9.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.11)
# Collecting requests>=2.26
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.4 MB/s
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Installing collected packages: requests, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# Successfully installed requests-2.28.1 yfinance-0.1.87

# %%
# Time Series Forecasting - Multivariate Time Series Models for Stock Market Prediction

import math  
import numpy as np 
import pandas as pd 
from datetime import date, timedelta, datetime 
from pandas.plotting import register_matplotlib_converters 
import matplotlib.pyplot as plt
import matplotlib.dates as mdates 
import tensorflow as tf
import tensorflow.keras as keras

from tensorflow.keras import Sequential 
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU, Dense, Dropout 
from tensorflow.keras.callbacks import EarlyStopping 

from sklearn.metrics import mean_absolute_error, mean_squared_error

from sklearn.preprocessing import RobustScaler, MinMaxScaler 
import seaborn as sns 
import yfinance as yf

print('Tensorflow Version: ' + tf.__version__)
physical_devices = tf.config.list_physical_devices('GPU')
print("Num GPUs:", len(physical_devices))
# Out:
# Tensorflow Version: 2.9.2
# Num GPUs: 1

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# # Preprocessing

# %%
def load(symbol,start_date,end_date):
  df = yf.download(symbol, start=start_date, end=end_date)
  return df

# %%
def count(start_date,end_date):
  end_date_object = datetime.strptime(end_date, '%Y-%m-%d').date()
  start_date_object = datetime.strptime(start_date, '%Y-%m-%d').date()
  return (end_date_object-start_date_object)

# %%
def plot(df):
  df_plot = df.copy()

  num_cols = 2
  num_rows = int(round(df_plot.shape[1] / num_cols, 0))

  fig, ax = plt.subplots(nrows=num_rows, ncols=num_cols, sharex=True, figsize=(20, 10))
  for i, ax in enumerate(fig.axes):
          sns.lineplot(data = df_plot.iloc[:, i], ax=ax)
          ax.tick_params(axis="x", rotation=30, labelsize=15, length=0)
          ax.xaxis.set_major_locator(mdates.AutoDateLocator())
  fig.tight_layout()
  plt.show()

# %%
def preprocess(df, seq_len, split=0.8):
  sequence_length = seq_len

  stock_features = ['High', 'Low', 'Open', 'Close', 'Volume']

  train_df = df.sort_values(by=['Date']).copy()

  data = pd.DataFrame(train_df)
  data_filtered = data[stock_features]

  data_filtered_ext = data_filtered.copy()
  data_filtered_ext['Prediction'] = data_filtered_ext['Close']

  data_filtered_ext.tail()

  nrows = data_filtered.shape[0]

  np_data_unscaled = np.array(data_filtered)
  np_data = np.reshape(np_data_unscaled, (nrows, -1))
  print(np_data.shape)

  scaler = MinMaxScaler()
  np_data_scaled = scaler.fit_transform(np_data_unscaled)

  scaler_pred = MinMaxScaler()
  df_Close = pd.DataFrame(data_filtered_ext['Close'])
  np_Close_scaled = scaler_pred.fit_transform(df_Close)

  index_Close = data.columns.get_loc("Close")

  train_data_len = math.ceil(np_data_scaled.shape[0] * split)

  train_data = np_data_scaled[0:train_data_len, :]
  val_data = np_data_scaled[train_data_len - sequence_length:, :]

  def partition_rnn(sequence_length, data):
      x, y = [], []
      data_len = data.shape[0]
      for i in range(sequence_length, data_len):
          x.append(data[i-sequence_length:i,:])
          y.append(data[i, index_Close])
      x = np.array(x)
      y = np.array(y)
      return x, y

  x_train, y_train = partition_rnn(sequence_length, train_data)
  x_val, y_val = partition_rnn(sequence_length, val_data)

  return stock_features, train_data_len, data_filtered_ext, scaler, scaler_pred, index_Close, x_train, y_train, x_val, y_val

# %% [markdown]
# # Build RNN model

# %%
def create_RNN(hidden_units, input_shape, rnn_type, lr, loss, drop=0.2):
  model = Sequential()
  if rnn_type == 'RNN':

    model.add(SimpleRNN(hidden_units, return_sequences=True, input_shape=input_shape)) 
    model.add(Dropout(drop))
    model.add(SimpleRNN(hidden_units, return_sequences=True))
    model.add(SimpleRNN(hidden_units, return_sequences=False))

  elif rnn_type == 'LSTM':

    model.add(LSTM(hidden_units, return_sequences=True, input_shape=input_shape)) 
    model.add(Dropout(drop))
    model.add(LSTM(hidden_units, return_sequences=True))
    model.add(LSTM(hidden_units, return_sequences=False))

  elif rnn_type == 'GRU':

    model.add(GRU(hidden_units, return_sequences=True, input_shape=input_shape)) 
    model.add(Dropout(drop))
    model.add(GRU(hidden_units, return_sequences=True))
    model.add(GRU(hidden_units, return_sequences=False))

  model.add(Dense(1))

  opt = keras.optimizers.Adam(learning_rate=lr)
  model.compile(optimizer=opt, loss=loss)

  return model

# %%
def loss_plot(history, epochs, rnn_type ="Vanilla RNN"):
  fig, ax = plt.subplots(figsize=(12, 5), sharex=True)
  sns.lineplot(data=history.history["loss"])
  sns.lineplot(data=history.history["val_loss"])
  plt.title(f"Loss Curve w/ {rnn_type}")
  plt.ylabel("Loss")
  plt.xlabel("Steps")
  plt.legend(["Train", "Val"], loc="upper left")
  plt.grid()
  plt.show()

# %%
def evaluate(model, x_train, y_train, x_val, y_val, scaler_pred, epoch, batch_size): #SimpleRNN_model | LSTM_model | GRU_model
  epochs = epoch
  batch_size = batch_size
  early_stop = EarlyStopping(monitor='loss', patience=5, verbose=1)
  history = model.fit(x_train, y_train, 
                      batch_size=batch_size, 
                      epochs=epochs,
                      validation_data=(x_val, y_val)
                      #,callbacks=[early_stop])
                    )
                      
          
  y_pred_scaled = model.predict(x_val)

  y_pred = scaler_pred.inverse_transform(y_pred_scaled)
  y_val_unscaled = scaler_pred.inverse_transform(y_val.reshape(-1, 1))

  MAE = mean_absolute_error(y_val_unscaled, y_pred)
  MAPE = np.mean((np.abs(np.subtract(y_val_unscaled, y_pred)/ y_val_unscaled))) * 100
  MDAPE = np.median((np.abs(np.subtract(y_val_unscaled, y_pred)/ y_val_unscaled)) ) * 100

  return history, y_pred, MAE, MAPE, MDAPE

# %%
def evaluate_plot(data_filtered_ext, train_data_len, y_pred, stockname, display_start_date = "2019-01-01", rnn_type= "LSTM" ):
  display_start_date = display_start_date
  val = pd.DataFrame(data_filtered_ext['Close'][train_data_len:]).rename(columns={'Close': 'y_val'})
  train = pd.DataFrame(data_filtered_ext['Close'][:train_data_len + 1]).rename(columns={'Close': 'y_train'})
  val.insert(1, "y_pred", y_pred, True)
  df_union = pd.concat([val,train])

  df_union_zoom = df_union[df_union.index > display_start_date]
  fig, ax1 = plt.subplots(figsize=(12, 5))
  plt.title(f"Stock Price Prediction w/ {rnn_type}")
  plt.ylabel(stockname)
  sns.lineplot(data=df_union_zoom[['y_train',  'y_val', 'y_pred']], linewidth=1.0, dashes=False, ax=ax1)
  plt.grid()
  plt.legend()
  plt.show()

# %% [markdown]
# # Stock company

# %%
symbol ='BKNG'
stock_company = 'Booking Holdings Inc'

start_date = '2018-01-01'
end_date =  date.today().strftime("%Y-%m-%d")

df = load(symbol,start_date, end_date)
print(df.head())

print(count(start_date, end_date))

plot(df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2018-01-02  1750.089966  1790.660034  1744.500000  1784.750000  1784.750000
# 2018-01-03  1790.229980  1829.020020  1785.000000  1824.160034  1824.160034
# 2018-01-04  1838.540039  1848.900024  1802.030029  1807.250000  1807.250000
# 2018-01-05  1820.180054  1825.500000  1805.800049  1823.540039  1823.540039
# 2018-01-08  1827.489990  1874.949951  1825.189941  1851.810059  1851.810059
#
#             Volume
# Date
# 2018-01-02  475500
# 2018-01-03  525000
# 2018-01-04  592600
# 2018-01-05  358600
# 2018-01-08  555600
# 1784 days, 0:00:00

# %% [markdown]
# # RNN

# %%
sequence_length = 100 #sliding_window 
stock_features, train_data_len, data_filtered_ext, scaler, scaler_pred, index_Close, x_train, y_train, x_val, y_val = preprocess(df, seq_len = sequence_length)

h0 = x_train.shape[1] * x_train.shape[2]
# Out:
# (1231, 5)

# %%
epoch=50
batch_size=32
lr=0.001
loss="mean_squared_error"


SimpleRNN_model = create_RNN(hidden_units = h0, input_shape=(x_train.shape[1], x_train.shape[2]), rnn_type='RNN', lr=lr, loss=loss)

history, y_pred_simplernn, MAE_simplernn, MAPE_simplernn, MDAPE_simplernn = evaluate(SimpleRNN_model, x_train, y_train, x_val, y_val, scaler_pred, epoch=epoch, batch_size=batch_size)
# Out:
# Epoch 1/50
# 28/28 [==============================] - 10s 233ms/step - loss: 5.1162 - val_loss: 1.1640
# Epoch 2/50
# 28/28 [==============================] - 6s 222ms/step - loss: 3.0778 - val_loss: 16.0942
# Epoch 3/50
# 28/28 [==============================] - 6s 222ms/step - loss: 4.5786 - val_loss: 4.3267
# Epoch 4/50
# 28/28 [==============================] - 7s 242ms/step - loss: 2.3799 - val_loss: 0.1172
# Epoch 5/50
# 28/28 [==============================] - 6s 225ms/step - loss: 0.1576 - val_loss: 0.0311
# Epoch 6/50
# 28/28 [==============================] - 6s 230ms/step - loss: 0.0323 - val_loss: 0.0276
# Epoch 7/50
# 28/28 [==============================] - 6s 220ms/step - loss: 0.0308 - val_loss: 0.0362
# Epoch 8/50
# 28/28 [==============================] - 6s 224ms/step - loss: 0.0304 - val_loss: 0.0279
# Epoch 9/50
# 28/28 [==============================] - 6s 220ms/step - loss: 0.0304 - val_loss: 0.0350
# Epoch 10/50
# 28/28 [==============================] - 6s 224ms/step - loss: 0.0310 - val_loss: 0.0392
# Epoch 11/50
# 28/28 [==============================] - 8s 289ms/step - loss: 0.0305 - val_loss: 0.0281
# Epoch 12/50
# 28/28 [==============================] - 6s 223ms/step - loss: 0.0297 - val_loss: 0.0447
# Epoch 13/50
# 28/28 [==============================] - 7s 257ms/step - loss: 0.0308 - val_loss: 0.0334
# Epoch 14/50
# 28/28 [==============================] - 8s 274ms/step - loss: 0.0306 - val_loss: 0.0273
# Epoch 15/50
# 28/28 [==============================] - 6s 221ms/step - loss: 0.0311 - val_loss: 0.0260
# Epoch 16/50
# 28/28 [==============================] - 6s 222ms/step - loss: 0.0311 - val_loss: 0.0273
# Epoch 17/50
# 28/28 [==============================] - 6s 219ms/step - loss: 0.0315 - val_loss: 0.0241
# Epoch 18/50
# 28/28 [==============================] - 6s 218ms/step - loss: 0.0282 - val_loss: 0.0270
# Epoch 19/50
# 28/28 [==============================] - 7s 246ms/step - loss: 0.0333 - val_loss: 0.0222
# Epoch 20/50
# 28/28 [==============================] - 7s 239ms/step - loss: 0.0271 - val_loss: 0.0232
# Epoch 21/50
# 28/28 [==============================] - 6s 222ms/step - loss: 0.0280 - val_loss: 0.0331
# Epoch 22/50
# 28/28 [==============================] - 6s 220ms/step - loss: 0.0263 - val_loss: 0.0201
# Epoch 23/50
# 28/28 [==============================] - 6s 219ms/step - loss: 0.0208 - val_loss: 0.0182
# Epoch 24/50
# 28/28 [==============================] - 6s 224ms/step - loss: 0.0222 - val_loss: 0.0365
# Epoch 25/50
# 28/28 [==============================] - 6s 221ms/step - loss: 0.0260 - val_loss: 0.0221
# Epoch 26/50
# 28/28 [==============================] - 6s 221ms/step - loss: 0.0249 - val_loss: 0.0255
# Epoch 27/50
# 28/28 [==============================] - 6s 224ms/step - loss: 0.0359 - val_loss: 0.0621
# Epoch 28/50
# 28/28 [==============================] - 6s 225ms/step - loss: 0.0394 - val_loss: 0.0520
# Epoch 29/50
# 28/28 [==============================] - 6s 222ms/step - loss: 0.0338 - val_loss: 0.0334
# Epoch 30/50
# 28/28 [==============================] - 6s 221ms/step - loss: 0.0236 - val_loss: 0.0140
# Epoch 31/50
# 28/28 [==============================] - 6s 223ms/step - loss: 0.0178 - val_loss: 0.0140
# Epoch 32/50
# 28/28 [==============================] - 6s 221ms/step - loss: 0.0190 - val_loss: 0.0221
# Epoch 33/50
# 28/28 [==============================] - 6s 220ms/step - loss: 0.0183 - val_loss: 0.0146
# Epoch 34/50
# 28/28 [==============================] - 6s 222ms/step - loss: 0.0186 - val_loss: 0.0186
# Epoch 35/50
# 28/28 [==============================] - 6s 219ms/step - loss: 0.0190 - val_loss: 0.0180
# Epoch 36/50
# 28/28 [==============================] - 6s 219ms/step - loss: 0.0154 - val_loss: 0.0270
# Epoch 37/50
# 28/28 [==============================] - 6s 219ms/step - loss: 0.0140 - val_loss: 0.0109
# Epoch 38/50
# 28/28 [==============================] - 6s 219ms/step - loss: 0.0166 - val_loss: 0.0341
# Epoch 39/50
# 28/28 [==============================] - 6s 220ms/step - loss: 0.0158 - val_loss: 0.0263
# Epoch 40/50
# 28/28 [==============================] - 6s 223ms/step - loss: 0.0176 - val_loss: 0.0120
# Epoch 41/50
# 28/28 [==============================] - 6s 221ms/step - loss: 0.0139 - val_loss: 0.0106
# Epoch 42/50
# 28/28 [==============================] - 6s 220ms/step - loss: 0.0166 - val_loss: 0.0144
# Epoch 43/50
# 28/28 [==============================] - 6s 225ms/step - loss: 0.0139 - val_loss: 0.0158
# Epoch 44/50
# 28/28 [==============================] - 6s 223ms/step - loss: 0.0125 - val_loss: 0.0220
# Epoch 45/50
# 28/28 [==============================] - 6s 225ms/step - loss: 0.0143 - val_loss: 0.0220
# Epoch 46/50
# 28/28 [==============================] - 6s 222ms/step - loss: 0.0128 - val_loss: 0.0141
# Epoch 47/50
# 28/28 [==============================] - 6s 221ms/step - loss: 0.0124 - val_loss: 0.0163
# Epoch 48/50
# 28/28 [==============================] - 6s 221ms/step - loss: 0.0123 - val_loss: 0.0248
# Epoch 49/50
# 28/28 [==============================] - 6s 221ms/step - loss: 0.0140 - val_loss: 0.0199
# Epoch 50/50
# 28/28 [==============================] - 6s 227ms/step - loss: 0.0126 - val_loss: 0.0113
# 8/8 [==============================] - 1s 30ms/step

# %%
loss_plot(history, epochs=epoch, rnn_type ="Vanilla RNN")

# %%
print(MAE_simplernn, MAPE_simplernn, MDAPE_simplernn)
# Out:
# 137.55664806831174 6.72287362228049 5.7870807643705895

# %%
evaluate_plot(data_filtered_ext, train_data_len, y_pred_simplernn, stock_company, display_start_date = start_date, rnn_type ="Vanilla RNN")

# %% [markdown]
# # LSTM

# %%
sequence_length = 100 #sliding_window 
stock_features, train_data_len, data_filtered_ext, scaler, scaler_pred, index_Close, x_train, y_train, x_test, y_test = preprocess(df, seq_len = sequence_length)
h0 = x_train.shape[1] * x_train.shape[2]
# Out:
# (1231, 5)

# %%
epoch=50
batch_size=32
lr=0.001
loss="mean_squared_error"
LSTM_model = create_RNN(hidden_units = h0, input_shape=(x_train.shape[1], x_train.shape[2]), rnn_type='LSTM',lr=lr, loss=loss)
history, y_pred_LSTM, MAE_LSTM, MAPE_LSTM, MDAPE_LSTM = evaluate(LSTM_model, x_train, y_train, x_test, y_test, scaler_pred, epoch=epoch, batch_size=batch_size)
# Out:
# Epoch 1/50
# 28/28 [==============================] - 10s 90ms/step - loss: 0.0649 - val_loss: 0.0101
# Epoch 2/50
# 28/28 [==============================] - 1s 54ms/step - loss: 0.0037 - val_loss: 0.0070
# Epoch 3/50
# 28/28 [==============================] - 1s 54ms/step - loss: 0.0032 - val_loss: 0.0067
# Epoch 4/50
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0030 - val_loss: 0.0073
# Epoch 5/50
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0032 - val_loss: 0.0059
# Epoch 6/50
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0029 - val_loss: 0.0055
# Epoch 7/50
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0027 - val_loss: 0.0053
# Epoch 8/50
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0025 - val_loss: 0.0048
# Epoch 9/50
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0024 - val_loss: 0.0057
# Epoch 10/50
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0025 - val_loss: 0.0045
# Epoch 11/50
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0021 - val_loss: 0.0046
# Epoch 12/50
# 28/28 [==============================] - 2s 56ms/step - loss: 0.0023 - val_loss: 0.0046
# Epoch 13/50
# 28/28 [==============================] - 2s 58ms/step - loss: 0.0031 - val_loss: 0.0061
# Epoch 14/50
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0024 - val_loss: 0.0037
# Epoch 15/50
# 28/28 [==============================] - 2s 56ms/step - loss: 0.0020 - val_loss: 0.0036
# Epoch 16/50
# 28/28 [==============================] - 2s 56ms/step - loss: 0.0019 - val_loss: 0.0039
# Epoch 17/50
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0019 - val_loss: 0.0033
# Epoch 18/50
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 19/50
# 28/28 [==============================] - 2s 56ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 20/50
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0021 - val_loss: 0.0037
# Epoch 21/50
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0019 - val_loss: 0.0049
# Epoch 22/50
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0021 - val_loss: 0.0032
# Epoch 23/50
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0016 - val_loss: 0.0035
# Epoch 24/50
# 28/28 [==============================] - 2s 56ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 25/50
# 28/28 [==============================] - 2s 56ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 26/50
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 27/50
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 28/50
# 28/28 [==============================] - 2s 57ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 29/50
# 28/28 [==============================] - 2s 56ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 30/50
# 28/28 [==============================] - 2s 56ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 31/50
# 28/28 [==============================] - 2s 56ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 32/50
# 28/28 [==============================] - 2s 56ms/step - loss: 0.0013 - val_loss: 0.0024
# Epoch 33/50
# 28/28 [==============================] - 2s 56ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 34/50
# 28/28 [==============================] - 2s 56ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 35/50
# 28/28 [==============================] - 2s 56ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 36/50
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0013 - val_loss: 0.0029
# Epoch 37/50
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 38/50
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 39/50
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 40/50
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0013 - val_loss: 0.0025
# Epoch 41/50
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 42/50
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 43/50
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 44/50
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 45/50
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 46/50
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 47/50
# 28/28 [==============================] - 2s 55ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 48/50
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 49/50
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 50/50
# 28/28 [==============================] - 2s 54ms/step - loss: 0.0012 - val_loss: 0.0017
# 8/8 [==============================] - 1s 17ms/step

# %%
loss_plot(history, epochs=epoch)

# %%
print(MAE_LSTM, MAPE_LSTM, MDAPE_LSTM)
# Out:
# 48.504540916380854 2.34236074412835 1.907758725378305

# %%
evaluate_plot(data_filtered_ext, train_data_len, y_pred_LSTM, stock_company, display_start_date = start_date) #  "2019-01-01" )

# %% [markdown]
# # GRU

# %%
sequence_length = 100 #sliding_window 
stock_features, train_data_len, data_filtered_ext, scaler, scaler_pred, index_Close, x_train, y_train, x_val, y_val = preprocess(df, seq_len = sequence_length)

h0 = x_train.shape[1] * x_train.shape[2]
# Out:
# (1231, 5)

# %%
epoch=50
batch_size=32
lr=0.001
loss="mean_squared_error"

GRU_model = create_RNN(hidden_units = h0, input_shape=(x_train.shape[1], x_train.shape[2]),  rnn_type='GRU',lr=lr, loss=loss)
history, y_pred_GRU, MAE_GRU, MAPE_GRU, MDAPE_GRU = evaluate(GRU_model, x_train, y_train, x_val, y_val, scaler_pred, epoch=epoch, batch_size=batch_size)
# Out:
# Epoch 1/50
# 28/28 [==============================] - 6s 78ms/step - loss: 0.0572 - val_loss: 0.0073
# Epoch 2/50
# 28/28 [==============================] - 1s 45ms/step - loss: 0.0030 - val_loss: 0.0032
# Epoch 3/50
# 28/28 [==============================] - 1s 45ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 4/50
# 28/28 [==============================] - 1s 45ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 5/50
# 28/28 [==============================] - 1s 45ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 6/50
# 28/28 [==============================] - 1s 45ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 7/50
# 28/28 [==============================] - 1s 45ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 8/50
# 28/28 [==============================] - 1s 45ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 9/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0014 - val_loss: 0.0034
# Epoch 10/50
# 28/28 [==============================] - 1s 45ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 11/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 12/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 13/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 14/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 15/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 16/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0010 - val_loss: 0.0021
# Epoch 17/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 18/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.7377e-04 - val_loss: 0.0017
# Epoch 19/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 20/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.7723e-04 - val_loss: 0.0017
# Epoch 21/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 22/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0012 - val_loss: 0.0025
# Epoch 23/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 24/50
# 28/28 [==============================] - 1s 46ms/step - loss: 8.8725e-04 - val_loss: 0.0015
# Epoch 25/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.2416e-04 - val_loss: 0.0016
# Epoch 26/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.1880e-04 - val_loss: 0.0015
# Epoch 27/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.0862e-04 - val_loss: 0.0015
# Epoch 28/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.0529e-04 - val_loss: 0.0015
# Epoch 29/50
# 28/28 [==============================] - 1s 46ms/step - loss: 8.7140e-04 - val_loss: 0.0017
# Epoch 30/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.4471e-04 - val_loss: 0.0016
# Epoch 31/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.1993e-04 - val_loss: 0.0016
# Epoch 32/50
# 28/28 [==============================] - 1s 48ms/step - loss: 9.9191e-04 - val_loss: 0.0021
# Epoch 33/50
# 28/28 [==============================] - 1s 47ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 34/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.4917e-04 - val_loss: 0.0018
# Epoch 35/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.2768e-04 - val_loss: 0.0015
# Epoch 36/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 37/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.4813e-04 - val_loss: 0.0017
# Epoch 38/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 39/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 40/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 41/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.0576e-04 - val_loss: 0.0021
# Epoch 42/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.9094e-04 - val_loss: 0.0015
# Epoch 43/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.9566e-04 - val_loss: 0.0016
# Epoch 44/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0010 - val_loss: 0.0026
# Epoch 45/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.5624e-04 - val_loss: 0.0015
# Epoch 46/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.3109e-04 - val_loss: 0.0018
# Epoch 47/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.6819e-04 - val_loss: 0.0015
# Epoch 48/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.1775e-04 - val_loss: 0.0015
# Epoch 49/50
# 28/28 [==============================] - 1s 46ms/step - loss: 9.5178e-04 - val_loss: 0.0017
# Epoch 50/50
# 28/28 [==============================] - 1s 46ms/step - loss: 0.0012 - val_loss: 0.0015
# 8/8 [==============================] - 1s 15ms/step

# %%
print(MAE_GRU, MAPE_GRU, MDAPE_GRU)
# Out:
# 45.09119992139863 2.1923491925780696 1.6154972494124846

# %%
loss_plot(history, epochs=epoch, rnn_type ="GRU")

# %%
print(MAE_GRU, MAPE_GRU, MDAPE_GRU)
# Out:
# 45.09119992139863 2.1923491925780696 1.6154972494124846

# %%
evaluate_plot(data_filtered_ext, train_data_len, y_pred_GRU, stock_company, display_start_date = start_date, rnn_type ="GRU")

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.lineplot(data=y_pred_simplernn)
sns.lineplot(data=y_pred_LSTM, palette="Set1")
sns.lineplot(data=y_pred_GRU,  palette="Set2")
plt.title("Comparion on stock prediction models")
plt.ylabel("y_pred")
plt.xlabel("Steps")
plt.legend(["RNN", "LSTM", "GRU"], loc="upper left")
plt.grid()
plt.show()
